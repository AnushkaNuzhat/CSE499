# %%
pip install happytransformer
# Out:
# ...
#      |████████████████████████████████| 45 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 37.5 MB/s
# ...
#      |████████████████████████████████| 311 kB 49.3 MB/s
# ...
#      |████████████████████████████████| 134 kB 51.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 20.8 MB/s
# ...
#      |████████████████████████████████| 67 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 212 kB 21.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 46.2 MB/s
# ...
#      |████████████████████████████████| 895 kB 41.8 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 34.8 MB/s
# ...
#      |████████████████████████████████| 271 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 144 kB 36.7 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.5 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from happytransformer import HappyGeneration

# %%
happy_gen = HappyGeneration("GPT-NEO","EleutherAI/gpt-neo-125M")
# Out:
# Downloading:   0%|          | 0.00/0.98k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/502M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]
# 03/04/2022 16:57:43 - INFO - happytransformer.happy_transformer -   Using model: cuda

# %% [markdown]
# Modify

# %%
from happytransformer import GENSettings

# %%
args = GENSettings(no_repeat_ngram_size=2)

# %%
top_k_sampling_settings = GENSettings(do_sample=True, early_stopping= False, top_k = 50, temperature = 0.7)

# %% [markdown]
# TRAIN

# %%
from happytransformer import GENTrainArgs

# %%
args = GENTrainArgs(num_train_epochs = 1)

# %%
happy_gen.train("train.txt",args=args)
# Out:
# 03/04/2022 17:01:14 - INFO - happytransformer.happy_transformer -   Preprocessing dataset...
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-421274da7a2c1bce/0.0.0/08f6fb1dd2dab0a18ea441c359e1d63794ea8cb53e7863e6edf8fc5655e47ec4. Subsequent calls will reuse this data.
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]
# 03/04/2022 17:01:16 - INFO - happytransformer.happy_transformer -   Training...
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 13
#   Num Epochs = 1
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
# ...

# %%
result = happy_gen.generate_text("manager day overwhelming",args=top_k_sampling_settings)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result.text)
# Out:
#  is a strong feature of the game, and the team does not need to come up with new or better ways to improve the game.
#
# In the game, the team has to be able to change the game, and they have to have a
